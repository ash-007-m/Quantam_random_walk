# %%
import numpy as np
import math
import random 
import numpy.linalg as la
import matplotlib.pyplot as plt

# %%
#part a
d=[-1,1]
def simulate_random_walk():
 t=[0]
 x=[0]
 while(t[-1]<100):
  i=random.choice(d)
  x.append(x[-1]+i)
  t.append(t[-1]+1)
 plt.plot(t,x)


simulate_random_walk()
plt.show()

# %%
def simulate(j):
 t=[0]
 x=[0]
 while(t[-1]<100):
  i=random.choice(d)
  x.append(x[-1]+i)
  t.append(t[-1]+1)
 plt.plot(t,x,label=f"{j}")
 return x[-1]

dis=np.full(100,0)

for i in range(100):
    random.seed(i)
    dis[i]=(simulate(i))
    
#plt.legend()
plt.show() 

plt.hist(dis, bins=5, edgecolor='black', alpha=1, label='dis')
plt.show()

# %%
for i in range(100):
    random.seed(i)
    steps = [random.choice([-1, 1]) for _ in range(100)]
    print(f"Seed: {i}, Steps: {steps}")
